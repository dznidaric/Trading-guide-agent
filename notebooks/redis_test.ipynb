# %%
import os, ssl
from dotenv import load_dotenv
load_dotenv()
#redis_url = os.getenv("REDIS_URL")
redis_url = "rediss://redis-14894.c328.europe-west3-1.gce.cloud.redislabs.com:14894"

# %%
import socket
socket.create_connection(("192.168.255.60", 8080), timeout=5).close()
print("proxy:8080 OK")
# Out:
# proxy:8080 OK

# %%
redis_url ="redis://default:AZMQAAIncDE5YzI4ZGM5OWYyZmM0ODZjYTljOGU2NTZiZDdiYzM3ZXAxMzc2NDg@logical-ladybird-37648.upstash.io:443"

# %%
import socket
from urllib.parse import urlparse

u = urlparse(os.environ["REDIS_URL"])
sock = socket.create_connection(("logical-ladybird-37648.upstash.io", "443"), timeout=5)
sock.close()
print("TCP OK")
# Out:
# ---------------------------------------------------------------------------
# UnicodeError                              Traceback (most recent call last)
# Cell In[21], line 5
#       2 from urllib.parse import urlparse
#       4 u = urlparse(os.environ["REDIS_URL"])
# ----> 5 sock = socket.create_connection(("rediss://default:AZMQAAIncDE5YzI4ZGM5OWYyZmM0ODZjYTljOGU2NTZiZDdiYzM3ZXAxMzc2NDg@logical-ladybird-37648.upstash.io:6379", "443"), timeout=5)
#       6 sock.close()
#       7 print("TCP OK")
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\socket.py:841, in create_connection(address, timeout, source_address, all_errors)
#     839 host, port = address
#     840 exceptions = []
# --> 841 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     842     af, socktype, proto, canonname, sa = res
#     843     sock = None
#
# ...

# %%
https://logical-ladybird-37648.upstash.io
